# %%
import cv2

# %%
aws_access_key_id="ASIAVOGBA4U57FBVTG5I"
aws_secret_access_key="ova7Lcpeqs0V3H4e4gUhqQiTmOzqbMR7UaQgmdz+"
aws_session_token=""

import boto3
import json
import pandas as pd
import numpy as np

# %%
vid_names_labels=pd.read_csv("video_names_label.csv")
num_vids=vid_names_labels.file_name.size

# %%
#This method takes an image and detects 8 emotions and return it
def detect_sentiment(photo):
#         photo = "split_images/image1.jpg"

        client = boto3.client('rekognition',
                                aws_access_key_id = aws_access_key_id,
                                aws_secret_access_key = aws_secret_access_key,
                                aws_session_token = aws_session_token, region_name="us-east-1")

        with open(photo, 'rb') as source_image:
            final_image = source_image.read()

        response = client.detect_faces(Image={
                'Bytes': final_image
                },Attributes=['ALL'])

        personFound = False
        personConfidence = 100

        fireFound = False
        fireConfidence = 100
        print('Detected faces for ' + photo)    
        for faceDetail in response['FaceDetails']:
            print('The detected face is between ' + str(faceDetail['AgeRange']['Low']) 
                  + ' and ' + str(faceDetail['AgeRange']['High']) + ' years old')
#             print('Here are the other attributes:')
#             print(json.dumps(faceDetail, indent=4, sort_keys=True))
#             print(faceDetail["Emotions"][0])
            return faceDetail["Emotions"]

# %%
#Creating an empty dataframe with appropiate col names
returned_emotions=detect_sentiment("split_images/image1.jpg") #for getting the emotion names
li_col_name=['vid_name'] #need to set it statically for optimization
for i in range(0,8):            
    li_col_name.append(returned_emotions[i]['Type'])
df_emotions=pd.DataFrame(data=[],columns=li_col_name) #dataframe which will hold the frame by frame emotions
# Out:
# Detected faces for split_images/image1.jpg
# The detected face is between 23 and 35 years old

# %%
df_emotions
num_vids
# Out:
# 39

# %%
#inserting each frame emotion values in the dataframe
for j in range(30,num_vids):
    vid_name=vid_names_labels.iloc[j].file_name
    vidcap = cv2.VideoCapture("dataset/"+vid_name+".MOV")
    
    
    def getFrame(sec):
        vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
        hasFrames,image = vidcap.read()
        if hasFrames:
            cv2.imwrite("split_images/"+vid_name+"_"+str(count)+".jpg", image)     # save frame as JPG file
        return hasFrames
    sec = 0
    frameRate = 0.5 #//it will capture image in each 0.5 second
    count=1
    success = getFrame(sec)
    while success:
        count = count + 1
        sec = sec + frameRate
        sec = round(sec, 2)
        success = getFrame(sec)
        
    no_face_count=0
    for image_num in range(1,count):
        returned_emotions=detect_sentiment(f"split_images/{vid_name}_{image_num}.jpg")
        if(returned_emotions==None):
            no_face_count+=1
        else: 
            print(row_num)
            for i in range(0,8):            
                df_emotions.loc[row_num,returned_emotions[i]['Type']]=returned_emotions[i]['Confidence']
                df_emotions.loc[row_num,'vid_name']=vid_name
            row_num+=1
# Out:
# Detected faces for split_images/IMG_9745_1.jpg
# The detected face is between 13 and 25 years old
# 1499
# Detected faces for split_images/IMG_9745_2.jpg
# The detected face is between 12 and 22 years old
# 1500
# Detected faces for split_images/IMG_9745_3.jpg
# The detected face is between 13 and 23 years old
# 1501
# Detected faces for split_images/IMG_9745_4.jpg
# The detected face is between 13 and 25 years old
# 1502
# Detected faces for split_images/IMG_9745_5.jpg
# The detected face is between 34 and 50 years old
# 1503
# Detected faces for split_images/IMG_9745_6.jpg
# The detected face is between 13 and 25 years old
# 1504
# Detected faces for split_images/IMG_9745_7.jpg
# The detected face is between 12 and 22 years old
# 1505
# Detected faces for split_images/IMG_9745_8.jpg
# The detected face is between 12 and 22 years old
# 1506
# Detected faces for split_images/IMG_9745_9.jpg
# The detected face is between 13 and 25 years old
# 1507
# ...

# %%
df_emotions
# Out:
#       vid_name      CALM        SAD     HAPPY     ANGRY SURPRISED  CONFUSED  \
# 0     IMG_9704   45.3296    14.5014   1.14231   3.74992   3.34098   12.0349
# 1     IMG_9704   27.4815     6.6234   1.64643   3.50848    6.8202   28.8102
# 2     IMG_9704   82.5496    3.31778   1.32403   1.84233   1.51487   4.00306
# 3     IMG_9704   69.8203     7.5283  0.887512   1.07808  0.226921    2.4734
# 4     IMG_9704   96.8174   0.733943  0.135913  0.323881  0.186662  0.867073
# ...        ...       ...        ...       ...       ...       ...       ...
# 1880  IMG_9755   3.27641   0.392145   89.6458   1.20725   3.47294  0.807719
# 1881  IMG_9755   2.79111   0.374125   91.9144  0.893301   2.34444  0.734553
# 1882  IMG_9755  0.197604  0.0470323   98.1458   0.24879  0.945673  0.178237
# 1883  IMG_9755  0.142665  0.0356377   98.3118  0.198433  0.943295  0.149031
# 1884  IMG_9755  0.349842  0.0768323    97.184  0.225533   1.57087  0.241162
#
#      DISGUSTED       FEAR
# 0      6.30571    13.5951
# ...

# %%
df_emotions.shape
# Out:
# (1352, 9)

# %%
df_emotions.to_csv("emotions_all.csv",encoding='utf-8', index=False)

# %%
row_num
# Out:
# 398
